# %%
# load quicc-dynavis from local path
import sys
sys.path.append('/Users/yuanlonghui/quicc-dynavis/src')
import importlib
from quicc_dynavis import spectra
importlib.reload(spectra)

basefolder = "/Users/yuanlonghui/IlessDyn_Lin"
startFolder= basefolder+'/Data/IlessDyn_Lin_E2e-6/simu_quicc/N127_dt5e-9_blowup'
save_dir   = basefolder+"/Results/IlessDyn_Lin_E2e-6"

# %%
#spectra plot
fig, axes, path = spectra.plot_spectra(
    folderFile=startFolder,
    save_dir = save_dir+'/spectra',
    mode="single",
    #mode = 'average', start_time=0, stop_time=1,
    which="last", show=True
)

# %%
from quicc_dynavis import timeseries
importlib.reload(timeseries)
fig = timeseries.plot_energy_timeseries(
    folderFile=startFolder,
    save_dir = save_dir+'/timeseries',
)
